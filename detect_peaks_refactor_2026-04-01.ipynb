# %%
import importlib
import detect_peaks_refactor as peaks
import peak_detection.data_io as data_io
import os

importlib.reload(data_io)
importlib.reload(peaks)

apt_file = 'APT_test\\R13_40310Zr Unsaved - Top Level ROI.csv'
rrng_file = 'RRNG_test\\R13_40310Zr Top Level ROI.RRNG'
output_dir = os.path.join(os.getcwd(), 'gg2')
#result = peaks.process_dataset(apt_file, rrng_file, output_dir='gg2', flag_unknowns=True)
# TODO: Consider changing default training path to what's specified here
training_path='peak_detection/Ionclassifier/training_data/NewData_peakshift0_noise0/Data0001'
result = peaks.process_dataset(apt_file, rrng_file, output_dir='gg2', flag_unknowns=True, use_mc_distance=True, mc_threshold=0.2, save_rrng_output=True
                               , training_path=training_path)
# Out:
# Detecting peaks for gg2 (Zoom: None)...
# Loading CSV: APT_test\R13_40310Zr Unsaved - Top Level ROI.csv
#   Metadata saved: gg2/gg2_rf_elements.txt, gg2/gg2_true_species.txt
# Start inference
# Speed:  48.9ms inference, 5.5ms postprocess for per spectrum
# Training RF model on base elements: ['Al', 'C', 'Co', 'Cu', 'Ga', 'H', 'Ni', 'Ti', 'Zr']
# Explicit classes from RRNG: ['Al', 'C', 'Co', 'Cu', 'Ga', 'H', 'H2', 'Ni', 'Ti', 'Zr', 'ZrH']
# Loading and parsing classifier training data: 100%|██████████| 1000/1000 [00:02<00:00, 385.03it/s]
# Loaded training data with feature vector length: 20 (Neighborhood: 10, Signature: 10)
#   Training KDE verification model using: peak_detection/Ionclassifier/training_data/NewData_peakshift0_noise0/Data0001 (Molecules: False)...
# Loading and parsing classifier training data: 100%|██████████| 1000/1000 [00:02<00:00, 439.07it/s]
# Loaded training data with feature vector length: 1 (Neighborhood: 1, Signature: 0)
#   Unlikely RF predictions flagged. Suggestions saved to gg2\gg2_element_suggestions.txt
#   Detailed results saved to gg2/gg2_detailed_results.csv
#   Accuracy results saved to gg2/gg2_rf_accuracy.txt
#   Building empirical m/c distributions for Unknown peak suggestions...
#   Unknown Peak Suggestions saved to gg2/gg2_unknown_predictions.txt
#   Total Combined Metrics: Precision=0.943, Recall=1.000, F1=0.971
# Ranges saved to gg2\gg2_peak_ranges.txt
# Predicted RRNG saved to gg2\gg2_predicted.RRNG
# Manual RRNG ranges: 34
# Saved comparison plot to gg2\gg2_yolo_1d_model_comparison.png

# %%
data_io.save_rrng(os.path.join(output_dir, 'rrng_test.rrng'), result["detected_ranges"])
# Out:
# woohoo!

# %%
result['detected_ranges']
# Out:
# [{'pos': 55.0301171875,
#   'start': 54.95884765625,
#   'end': 55.10138671875,
#   'label': 'Unknown (Co)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 11.9943994140625,
#   'start': 11.97390625,
#   'end': 12.014892578125,
#   'label': 'C (0.48), H (0.24)',
#   'id_score': 0.48,
#   'method': 'RF',
#   'detailed_id': {'el1': 'C', 'conf1': 0.48, 'el2': 'H', 'conf2': 0.24}},
#  {'pos': 25.0281005859375,
#   'start': 24.917138671875,
#   'end': 25.1390625,
#   'label': 'Ti (0.76), Zr (0.16)',
#   'id_score': 0.76,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 0.76, 'el2': 'Zr', 'conf2': 0.16}},
#  {'pos': 60.0769384765625,
#   'start': 59.774121093750004,
#   'end': 60.379755859375,
#   'label': 'Unknown (Ni)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 31.3109521484375,
#   'start': 31.2311669921875,
#   'end': 31.3907373046875,
#   'label': 'Zr (1.00)',
#   'id_score': 1.0,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Zr', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 61.984052734375,
#   'start': 61.853212890625,
#   'end': 62.114892578125,
#   'label': 'Ni (0.80), Ga (0.08)',
#   'id_score': 0.8,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ni', 'conf1': 0.8, 'el2': 'Ga', 'conf2': 0.08}},
#  {'pos': 63.712363281250006,
#   'start': 62.753125000000004,
#   'end': 64.6716015625,
#   'label': 'Unknown (Cu)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 58.680361328125,
#   'start': 57.7252099609375,
#   'end': 59.6355126953125,
#   'label': 'Unknown (Cu)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 32.47970947265625,
#   'start': 32.44107177734375,
#   'end': 32.51834716796875,
#   'label': 'Cu (0.68), Zr (0.24)',
#   'id_score': 0.68,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Cu', 'conf1': 0.68, 'el2': 'Zr', 'conf2': 0.24}},
#  {'pos': 27.42376708984375,
#   'start': 26.906376953125,
#   'end': 27.9411572265625,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 70.9275390625,
#   'start': 70.841962890625,
#   'end': 71.01311523437501,
#   'label': 'Unknown (Cu)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 66.385107421875,
#   'start': 64.69970703125,
#   'end': 68.0705078125,
#   'label': 'Unknown (Cu)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 68.92655273437501,
#   'start': 68.843984375,
#   'end': 69.00912109375,
#   'label': 'Unknown (Cu)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 48.013510742187506,
#   'start': 47.86517578125,
#   'end': 48.161845703125,
#   'label': 'Ti (0.44), Zr (0.32)',
#   'id_score': 0.44,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 0.44, 'el2': 'Zr', 'conf2': 0.32}},
#  {'pos': 60.9761962890625,
#   'start': 60.860561523437504,
#   'end': 61.0918310546875,
#   'label': 'Ni (0.28), Cu (0.20)',
#   'id_score': 0.28,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ni', 'conf1': 0.28, 'el2': 'Cu', 'conf2': 0.2}},
#  {'pos': 1.1944089508056641,
#   'start': 0.9988381958007813,
#   'end': 1.389979705810547,
#   'label': 'H (0.92)',
#   'id_score': 0.92,
#   'method': 'RF',
#   'detailed_id': {'el1': 'H', 'conf1': 0.92, 'el2': '', 'conf2': 0.0}},
#  {'pos': 23.5817578125,
#   'start': 23.3903955078125,
#   'end': 23.7731201171875,
#   'label': 'Ti (1.00)',
#   'id_score': 1.0,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 24.60056884765625,
#   'start': 24.38528564453125,
#   'end': 24.81585205078125,
#   'label': 'Ti (0.84), Zr (0.12)',
#   'id_score': 0.84,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 0.84, 'el2': 'Zr', 'conf2': 0.12}},
#  {'pos': 23.07202880859375,
#   'start': 22.906904296875002,
#   'end': 23.2371533203125,
#   'label': 'Ti (1.00)',
#   'id_score': 1.0,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 47.028232421875,
#   'start': 46.838642578125004,
#   'end': 47.217822265625,
#   'label': 'Ti (0.48), Zr (0.40)',
#   'id_score': 0.48,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 0.48, 'el2': 'Zr', 'conf2': 0.4}},
#  {'pos': 15.56986572265625,
#   'start': 13.47970458984375,
#   'end': 17.66002685546875,
#   'label': 'Unknown (Co)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 31.97734130859375,
#   'start': 31.923986816406252,
#   'end': 32.03069580078125,
#   'label': 'Zr (0.72), Cu (0.20)',
#   'id_score': 0.72,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Zr', 'conf1': 0.72, 'el2': 'Cu', 'conf2': 0.2}},
#  {'pos': 45.532724609375,
#   'start': 45.294130859375,
#   'end': 45.771318359375,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 29.3237548828125,
#   'start': 28.86421142578125,
#   'end': 29.78329833984375,
#   'label': 'Ni (0.64), Co (0.24)',
#   'id_score': 0.64,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ni', 'conf1': 0.64, 'el2': 'Co', 'conf2': 0.24}},
#  {'pos': 30.6592529296875,
#   'start': 30.5668115234375,
#   'end': 30.7516943359375,
#   'label': 'Zr (1.00)',
#   'id_score': 1.0,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Zr', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 30.324775390625,
#   'start': 30.2467822265625,
#   'end': 30.4027685546875,
#   'label': 'Zr (0.96)',
#   'id_score': 0.96,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Zr', 'conf1': 0.96, 'el2': '', 'conf2': 0.0}},
#  {'pos': 48.477939453125,
#   'start': 48.410927734375,
#   'end': 48.544951171875,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 2.074532470703125,
#   'start': 1.9859597778320313,
#   'end': 2.163105163574219,
#   'label': 'Unknown (H)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 30.967951660156253,
#   'start': 30.90652587890625,
#   'end': 31.02937744140625,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 46.534033203125,
#   'start': 46.367490234375,
#   'end': 46.700576171875,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 47.565068359375005,
#   'start': 47.3746484375,
#   'end': 47.75548828125,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 30.04738037109375,
#   'start': 29.8661181640625,
#   'end': 30.228642578125,
#   'label': 'Zr (0.64), Ni (0.32)',
#   'id_score': 0.64,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Zr', 'conf1': 0.64, 'el2': 'Ni', 'conf2': 0.32}},
#  {'pos': 24.1037451171875,
#   'start': 23.8771044921875,
#   'end': 24.330385742187502,
#   'label': 'Ti (0.96)',
#   'id_score': 0.96,
#   'method': 'RF',
#   'detailed_id': {'el1': 'Ti', 'conf1': 0.96, 'el2': '', 'conf2': 0.0}},
#  {'pos': 46.021787109375,
#   'start': 45.79296875,
#   'end': 46.25060546875,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}},
#  {'pos': 45.0406298828125,
#   'start': 44.788837890625004,
#   'end': 45.292421875,
#   'label': 'Unknown (Zr)',
#   'id_score': 1.0,
#   'method': 'RF (Filtered)',
#   'detailed_id': {'el1': 'Unknown', 'conf1': 1.0, 'el2': '', 'conf2': 0.0}}]
